# %% [markdown]
# <a href="https://colab.research.google.com/github/danasaur/nlp/blob/main/hugging_face_poetry_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 37.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 26.3 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
merve_dataset = load_dataset("merve/poetry")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/merve___csv/merve--poetry-f27664155e5efc39/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
merve_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['author', 'content', 'poem name', 'age', 'type'],
#         num_rows: 573
#     })
# })

# %%
#merve_dataset["train"][0]

# %%
shahules786_dataset = load_dataset("shahules786/PoetryFoundationData")
# Out:
# ...
# Generating train split:   0%|          | 0/13854 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/shahules786___parquet/shahules786--PoetryFoundationData-2588d38fb7ed0bba/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
shahules786_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['poem name', 'content', 'author', 'type', 'age'],
#         num_rows: 13854
#     })
# })

# %%
matthh_dataset = load_dataset("matthh/gutenberg-poetry-corpus")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/matthh___csv/matthh--gutenberg-poetry-corpus-8a1b155a49e4a2f2/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
matthh_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'gid', 'content', 'author', 'title', 'author_birth'],
#         num_rows: 1191
#     })
# })

# %%
#matthh_dataset["train"][0]

# %%
isaacrehg_dataset = load_dataset("isaacrehg/poetry-detailed-analysis")
# Out:
# ...
# Generating train split:   0%|          | 0/14507 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/isaacrehg___parquet/isaacrehg--poetry-detailed-analysis-63eabe017b75b864/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
isaacrehg_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['_id', 'title', 'author', 'url', 'stanza_index', 'stanza_header', 'content', 'analysis'],
#         num_rows: 14507
#     })
# })

# %%
#isaacrehg_dataset["train"][1]

# %%
isaacrehg_summary_dataset = load_dataset("isaacrehg/poetry-summary")
# Out:
# ...
# Generating train split:   0%|          | 0/3420 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/isaacrehg___parquet/isaacrehg--poetry-summary-3700a5db81b0b26e/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
isaacrehg_summary_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['_id', 'title', 'author', 'url', 'summary'],
#         num_rows: 3420
#     })
# })

# %%
isaacrehg_summary_dataset["train"][0]
# Out:
# {'_id': 1,
#  'title': "'had i not been awake'",
#  'author': 'seamus heaney',
#  'url': 'https://poemanalysis.com/seamus-heaney/had-i-not-been-awake/',
#  'summary': 'In ‘Had I not been awake‘, Heaney brilliantly depicts the humming energy of life that surrounds us everyday, but we rarely have cause to notice. \n-----\nThe poem begins with an extension of the title, expressing the narrator’s gratitude for being awake as it meant he did not miss the ambiguous “it”. Much of the poem’s intrigue stems from what this thing may be. Heaney employs his typically evocative poetic eye to the natural world around the narrator, notably the wind and its sounds. As the poem continues, it becomes clear that the narrator draws strength and inspiration from the power of nature, which emboldens them to continue living. \n-----\nYou can read the full poem here.'}
