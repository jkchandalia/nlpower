# %% [markdown]
# <a href="https://colab.research.google.com/github/danasaur/nlp/blob/main/notebooks/hugging_face_poetry_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q datasets

# %%
from datasets import load_dataset

# %%
merve_dataset = load_dataset("merve/poetry")

# %%
merve_dataset

# %%
#merve_dataset["train"][0]

# %%
shahules786_dataset = load_dataset("shahules786/PoetryFoundationData")

# %%
shahules786_dataset

# %%
matthh_dataset = load_dataset("matthh/gutenberg-poetry-corpus")

# %%
matthh_dataset

# %%
#matthh_dataset["train"][0]

# %%
isaacrehg_dataset = load_dataset("isaacrehg/poetry-detailed-analysis")

# %%
isaacrehg_dataset

# %%
#isaacrehg_dataset["train"][0]

# %%
isaacrehg_summary_dataset = load_dataset("isaacrehg/poetry-summary")

# %%
isaacrehg_summary_dataset

# %%
isaacrehg_summary_dataset["train"][0]

# %%
shahules786_dataset['train']

# %% [markdown]
# Haiku Datasets

# %%
statworx_dataset = load_dataset("statworx/haiku")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/statworx___parquet/statworx--haiku-b95358ae05c47e38/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
statworx_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['source', 'text', 'text_phonemes', 'keywords', 'keyword_phonemes', 'gruen_score', 'text_punc'],
#         num_rows: 49024
#     })
# })

# %%
# these poems seem to be scraped from reddit to develop a haiku generator: https://github.com/bfbarry/HaikuBot
statworx_dataset["train"][10]
# Out:
# {'source': 'bfbarry',
#  'text': 'Empty bleeding womb. / Stark white faces, sad eyes say. / Sorry for your loss.',
#  'text_phonemes': 'ehmp|tiy bliy|daxng wuwm / staark wayt fey|saxz saed ayz sey / saa|riy faor yaor laos',
#  'keywords': 'bleeding womb',
#  'keyword_phonemes': 'bliy|daxng wuwm',
#  'gruen_score': 0.685433526,
#  'text_punc': None}

# %%
dugward_dataset = load_dataset("dugward/english_haiku")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/dugward___csv/dugward--english_haiku-8fb54dc2f35c7748/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dugward_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['content'],
#         num_rows: 128
#     })
# })

# %%
dugward_dataset["train"][0]
# Out:
# {'content': 'couds of the west---sunthere half an hour high---i see youalso face to face'}
